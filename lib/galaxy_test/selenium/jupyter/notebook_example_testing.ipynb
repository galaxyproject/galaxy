# %%
# Cell is tagged with 'parameters' so it can be parameterized with papermill,
# if config not overridden ./galaxy_selenium_context.yml can also be populated.
config = None

# %%
from galaxy_test.selenium.jupyter_context import init
gx_selenium_context = init(config)

# %%
gx_selenium_context.register()
history_id = gx_selenium_context.current_history_id()
gx_selenium_context.dataset_populator.new_dataset(history_id=history_id)
gx_selenium_context.home()

# %%
gx_selenium_context.screenshot("home")

# %%
# optional step that shows how to access ActionChains

from selenium.webdriver.common.action_chains import ActionChains
ac = ActionChains(gx_selenium_context.driver)
